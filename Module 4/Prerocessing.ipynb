# %%
import numpy as np
import cv2 as cv

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = np.load('precessed_data_logs.npy')

# %%
steering = data[0]
# Out:
# array(['/Users/ashishjangra/Documents/Programs/Module 4/IMG/center_2020_08_26_04_55_44_259.jpg',
#        ' /Users/ashishjangra/Documents/Programs/Module 4/IMG/left_2020_08_26_04_55_44_259.jpg',
#        ' /Users/ashishjangra/Documents/Programs/Module 4/IMG/right_2020_08_26_04_55_44_259.jpg',
#        0.01950932, 1.0, 0.0, 30.188640000000003], dtype=object)

# %%
data[0]
# Out:
# array(['/Users/ashishjangra/Documents/Programs/Module 4/IMG/center_2020_08_26_04_55_44_259.jpg',
#        ' /Users/ashishjangra/Documents/Programs/Module 4/IMG/left_2020_08_26_04_55_44_259.jpg',
#        ' /Users/ashishjangra/Documents/Programs/Module 4/IMG/right_2020_08_26_04_55_44_259.jpg',
#        0.01950932, 1.0, 0.0, 30.188640000000003], dtype=object)

# %%
imgs = []
steering = []

for i in range(len(data)):

    imgs.append('IMG/' + data[i][0].split('/')[-1])
    steering.append(data[i][3])

# %%
imgs = np.array(imgs)
steering = np.array(steering)

# %%
imgs[2]
# Out:
# 'IMG/center_2020_08_26_04_52_02_984.jpg'

# %%
steering[2]
# Out:
# -0.04962873

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs, steering, test_size = 0.2, random_state = 6)

# %%
for i in range(len(X_train)):
    if ('IMG/center_2020_08_26_04_52_02_984.jpg' == X_train[i]):
        print(i)
# Out:
# 728

# %%
X_train[728]
# Out:
# 'IMG/center_2020_08_26_04_52_02_984.jpg'

# %%
y_train[728]
# Out:
# -0.04962873

# %%
img.shape
# Out:
# (160, 320, 3)

# %%
plt.imshow(img)

# %%
len(X_train)
# Out:
# 2113
